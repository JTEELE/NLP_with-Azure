# %%
#Copyright (c) Microsoft Corporation. All rights reserved.
#Licensed under the MIT License.

# -*- coding: utf-8 -*-

import json
import os 
from pprint import pprint
import requests

'''
This sample makes a call to the Bing Web Search API with a query and returns relevant web search.
Documentation: https://docs.microsoft.com/en-us/bing/search-apis/bing-web-search/overview
'''

# Add your Bing Search V7 subscription key and endpoint to your environment variables.
subscription_key = os.environ['BINGNEWS_API']
endpoint = os.environ['BING_ENDPOINT'] + "v7.0/search"

# Query term(s) to search for. 
query = "Microsoft"

# Construct a request
mkt = 'en-US'
params = { 'q': query, 'mkt': mkt }
headers = { 'Ocp-Apim-Subscription-Key': subscription_key }

# Call the API
try:
    response = requests.get(endpoint, headers=headers, params=params)
    response.raise_for_status()

    print(f'Headers:{headers}')

    print(response.headers)

    print(f'JSON Response:{response}')

    pprint(response.json())
except Exception as ex:
    raise ex
# Out:
# Headers:{'Ocp-Apim-Subscription-Key': 'dfe5775926b34d1caa64bc7761766a1e'}
# {'Cache-Control': 'private, max-age=0', 'Content-Length': '5126', 'Content-Type': 'application/json; charset=utf-8', 'Content-Encoding': 'br', 'Expires': 'Thu, 10 Mar 2022 22:01:38 GMT', 'Vary': 'Accept-Encoding', 'P3P': 'CP="NON UNI COM NAV STA LOC CURa DEVa PSAa PSDa OUR IND"', 'X-SNR-Routing': '1', 'BingAPIs-TraceId': '617314C8BB4D437CBC227A589EECEE31', 'BingAPIs-SessionId': 'EC90C824041A4EB68606289A109A8E31', 'X-MSEdge-ClientID': '04D8711F49CB66CE33FC607C482D67A5', 'X-MSAPI-UserState': '558b', 'BingAPIs-Market': 'en-US', 'X-Search-ResponseInfo': 'InternalResponseTime=452,MSDatacenter=CH1B', 'X-Cache': 'CONFIG_NOCACHE', 'Accept-CH': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version,Sec-CH-UA-Mobile,Sec-CH-UA-Model,Sec-CH-UA-Platform,Sec-CH-UA-Platform-Version', 'X-MSEdge-Ref': 'Ref A: 617314C8BB4D437CBC227A589EECEE31 Ref B: DM2EDGE0818 Ref C: 2022-03-10T22:02:38Z', 'apim-request-id': 'fdf0b161-884e-4bed-942d-2ed0b2caf229', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'CSP-Billing-Usage': 'CognitiveServices.BingSearchV7.Transaction=1', 'Date': 'Thu, 10 Mar 2022 22:02:38 GMT'}
# JSON Response:<Response [200]>
# {'_type': 'SearchResponse',
#  'entities': {'value': [{'bingId': 'a093e9b9-90f5-a3d5-c4b8-5855e1b01f85',
#                          'contractualRules': [{'_type': 'ContractualRules/MediaAttribution',
#                                                'mustBeCloseToContent': True,
#                                                'targetPropertyName': 'image',
#                                                'url': 'http://www.microsoft.com/'}],
#                          'description': 'Microsoft Corporation is an American '
#                                         'multinational corporation '
#                                         'headquartered in Redmond, Washington, '
#                                         'that develops, manufactures, '
#                                         'licenses, supports and sells computer '
#                                         'software, consumer electronics and '
#                                         'personal computers and services. Its '
#                                         'best known software products are the '
#                                         'Microsoft Windows line of operating '
#                                         'systems, Microsoft Office office '
#                                         'suite, and Internet Explorer web '
#                                         'browser. Its flagship hardware '
#                                         'products are Xbox game console and '
#                                         'the Microsoft Surface series of '
#                                         "tablets. It is the world's largest "
#                                         'software maker measured by revenues. '
#                                         "It is also one of the world's most "
#                                         'valuable companies.',
#                          'entityPresentationInfo': {'entityScenario': 'DominantEntity',
#                                                     'entityTypeHints': ['Organization']},
#                          'id': 'https://api.bing.microsoft.com/api/v7/#Entities.0',
#                          'image': {'height': 110,
#                                    'hostPageUrl': 'http://upload.wikimedia.org/wikipedia/commons/thumb/9/96/Microsoft_logo_%282012%29.svg/500px-Microsoft_logo_%282012%29.svg.png',
#                                    'name': "Be What's Next",
#                                    'provider': [{'_type': 'Organization',
#                                                  'url': 'http://www.microsoft.com/'}],
#                                    'sourceHeight': 101,
#                                    'sourceWidth': 474,
#                                    'thumbnailUrl': 'https://www.bing.com/th?id=AMMS_1d05fa8398f7b1169c1187f837bbab9f&w=110&h=110&c=7&rs=1&qlt=95&cdv=1&pid=16.1',
#                                    'width': 110},
#                          'name': 'Microsoft',
#                          'url': 'https://www.microsoft.com/en-us/default.aspx',
#                          'webSearchUrl': 'https://www.bing.com/entityexplore?q=Microsoft&filters=sid:%22a093e9b9-90f5-a3d5-c4b8-5855e1b01f85%22&elv=AXXfrEiqqD9r3GuelwApulqqz04IJYHsKhYEmUe6LhjtXxdDPxlk10PGkY4uvpj7xzq3FpwOfS6mU0tfN0jF0bQ0rgyfQCIW9NvznRPYBosw'}]},
#  'news': {'id': 'https://api.bing.microsoft.com/api/v7/#News',
#           'readLink': 'https://api.bing.microsoft.com/api/v7/news/search?q=Microsoft',
#           'value': [{'about': [{'name': 'Pursuit',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/99600fe0-fc94-488c-1dc8-c895ba2f94eb'},
#                                {'name': 'Microsoft',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/a093e9b9-90f5-a3d5-c4b8-5855e1b01f85'},
#                                {'name': 'Climate',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/accff6a8-3045-c2ba-ebcd-469bf66b8df0'}],
#                      'category': 'ScienceAndTechnology',
#                      'contractualRules': [{'_type': 'ContractualRules/TextAttribution',
#                                            'text': 'New York Times'}],
#                      'datePublished': '2022-03-10T18:30:00.0000000Z',
#                      'description': 'The company aims to be “carbon negative” '
#                                     'by the end of the decade, but its '
#                                     'emissions rose sharply in the most recent '
#                                     'year measured.',
#                      'image': {'contentUrl': 'https://static01.nyt.com/images/2022/03/10/business/10sustain/10sustain-facebookJumbo.jpg',
#                                'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=OVFT.Q3CnwFSYfCbTJu725myqUy&pid=News',
#                                              'height': 366,
#                                              'width': 700}},
#                      'name': 'Microsoft’s Pursuit of Climate Goals Runs Into '
#                              'Headwinds',
#                      'provider': [{'_type': 'Organization',
#                                    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.GzcmUDr41J6Qc1JEQyNTCA&pid=news'}},
#                                    'name': 'New York Times'}],
#                      'url': 'https://www.nytimes.com/2022/03/10/business/microsoft-climate-carbon-emissions.html'},
#                     {'about': [{'name': 'Party game',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/83c503e4-734e-e569-893d-77c27175a417'}],
#                      'category': 'ScienceAndTechnology',
#                      'contractualRules': [{'_type': 'ContractualRules/TextAttribution',
#                                            'text': 'Engadget on MSN.com'}],
#                      'datePublished': '2022-03-10T21:14:49.0000000Z',
#                      'description': "You don't have to lean on a special tool "
#                                     'to know whether or not a Microsoft game '
#                                     'will play properly on your Steam Deck. '
#                                     'The Vergenotes Microsoft has published a '
#                                     'list of the Xbox Game Studios titles you '
#                                     "can play on Valve's handheld,",
#                      'image': {'contentUrl': 'https://img-s-msn-com.akamaized.net/tenant/amp/entityid/AAUTHiD.img?h=630&w=1200&m=6&q=60&o=t&l=f&f=jpg&x=595&y=80',
#                                'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=OVFT.OHv1I6cFZDwY5g0l3QQHgy&pid=News',
#                                              'height': 367,
#                                              'width': 700}},
#                      'mentions': [{'name': 'Party game'},
#                                   {'name': 'Microsoft'},
#                                   {'name': 'Steam'}],
#                      'name': 'Microsoft outlines Steam Deck support for its '
#                              'first-party games',
#                      'provider': [{'_type': 'Organization',
#                                    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.FPGiCjSpNWuR3YuGCSVHjA&pid=news'}},
#                                    'name': 'Engadget on MSN.com'}],
#                      'url': 'https://www.msn.com/en-us/entertainment/gaming/microsoft-outlines-steam-deck-support-for-its-first-party-games/ar-AAUTHiJ'},
#                     {'about': [{'name': 'Microsoft',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/a093e9b9-90f5-a3d5-c4b8-5855e1b01f85'},
#                                {'name': 'Carbon footprint',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/0bcb8958-8d87-041b-588b-aa7b9faf711f'},
#                                {'name': 'Microsoft Windows',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/16aeb6d9-9098-0a40-4970-8e46a4fcee12'}],
#                      'contractualRules': [{'_type': 'ContractualRules/TextAttribution',
#                                            'text': 'Windows Central on '
#                                                    'MSN.com'}],
#                      'datePublished': '2022-03-10T20:52:15.0000000Z',
#                      'description': 'Not every year will be a total win for '
#                                     'Microsoft in the sustainability '
#                                     'department if its 2021 report is anything '
#                                     'to go by.',
#                      'image': {'contentUrl': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2022/01/microsoft-logo-2022-2.jpg',
#                                'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=OVFT.frglMJFKvFUJcP-5IpAJty&pid=News',
#                                              'height': 525,
#                                              'width': 700}},
#                      'mentions': [{'name': 'Microsoft'},
#                                   {'name': 'Carbon footprint'},
#                                   {'name': 'Microsoft Windows'}],
#                      'name': "As Microsoft's revenue grew in 2021, so did its "
#                              'carbon footprint',
#                      'provider': [{'_type': 'Organization',
#                                    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.k6WgtcFldEJeVYyScp3IPg&pid=news'}},
#                                    'name': 'Windows Central on MSN.com'}],
#                      'url': 'https://www.msn.com/en-us/finance/other/as-microsofts-revenue-grew-in-2021-so-did-its-carbon-footprint/ar-AAUU5C5'},
#                     {'about': [{'name': 'Microsoft',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/a093e9b9-90f5-a3d5-c4b8-5855e1b01f85'}],
#                      'category': 'ScienceAndTechnology',
#                      'contractualRules': [{'_type': 'ContractualRules/TextAttribution',
#                                            'text': 'GeekWire on MSN.com'}],
#                      'datePublished': '2022-03-10T18:30:00.0000000Z',
#                      'description': 'Microsoft on Thursday released its annual '
#                                     'Environmental Sustainability Report for '
#                                     '2021, covering its progress on goals for '
#                                     'climate impacts, water conservation, '
#                                     'waste reduction and ecosystem protection.',
#                      'image': {'contentUrl': 'https://cdn.geekwire.com/wp-content/uploads/2022/03/Lucas-Joppa-and-Brad-Smith-Microsoft.jpg',
#                                'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=OVFT.dPFrmgn-9AY9qtGSz8iqNi&pid=News',
#                                              'height': 466,
#                                              'width': 700}},
#                      'mentions': [{'name': 'Microsoft'},
#                                   {'name': 'Carbon footprint'},
#                                   {'name': 'Get Smart'}],
#                      'name': 'Here’s why Microsoft’s carbon footprint grew 21% '
#                              'last year, as profits swelled',
#                      'provider': [{'_type': 'Organization',
#                                    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.8xuMx67galb6fHwFjOgRrA&pid=news'}},
#                                    'name': 'GeekWire on MSN.com'}],
#                      'url': 'https://www.msn.com/en-us/finance/other/here-e2-80-99s-why-microsoft-e2-80-99s-carbon-footprint-grew-21-25-last-year-as-profits-swelled/ar-AAUTre9'},
#                     {'about': [{'name': 'Paul Thurrott',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/d87a86ed-272f-5ece-cca6-d8c6ee0694c1'},
#                                {'name': 'Microsoft',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/a093e9b9-90f5-a3d5-c4b8-5855e1b01f85'},
#                                {'name': 'Sustainability',
#                                 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/b35754b4-61c6-6e53-845c-f5451d9379e3'}],
#                      'category': 'ScienceAndTechnology',
#                      'contractualRules': [{'_type': 'ContractualRules/TextAttribution',
#                                            'text': 'Thurrott'}],
#                      'datePublished': '2022-03-10T20:03:00.0000000Z',
#                      'description': 'Microsoft has released today its annual '
#                                     'sustainability report for 2021, where the '
#                                     'company detailed the progress it made '
#                                     'last year to become a carbon-negative '
#                                     'company by 2030.',
#                      'name': 'Microsoft Shares an Update on its Sustainability '
#                              'Commitments',
#                      'provider': [{'_type': 'Organization',
#                                    'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.hnrPDX6BS6-FnGt4E6YnHw&pid=news'}},
#                                    'name': 'Thurrott'}],
#                      'url': 'https://www.thurrott.com/microsoft/264092/microsoft-shares-an-update-on-its-sustainability-commitments'}]},
#  'queryContext': {'originalQuery': 'Microsoft'},
#  'rankingResponse': {'mainline': {'items': [{'answerType': 'WebPages',
#                                              'resultIndex': 0,
#                                              'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.0'}},
#                                             {'answerType': 'WebPages',
#                                              'resultIndex': 1,
#                                              'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.1'}},
#                                             {'answerType': 'WebPages',
#                                              'resultIndex': 2,
#                                              'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.2'}},
#                                             {'answerType': 'News',
#                                              'value': {'id': 'https://api.bing.microsoft.com/api/v7/#News'}},
#                                             {'answerType': 'WebPages',
#                                              'resultIndex': 3,
#                                              'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.3'}},
#                                             {'answerType': 'WebPages',
#                                              'resultIndex': 4,
#                                              'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.4'}},
#                                             {'answerType': 'WebPages',
#                                              'resultIndex': 5,
#                                              'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.5'}}]},
#                      'sidebar': {'items': [{'answerType': 'Entities',
#                                             'resultIndex': 0,
#                                             'value': {'id': 'https://api.bing.microsoft.com/api/v7/#Entities.0'}}]}},
#  'webPages': {'totalEstimatedMatches': 2240000000,
#               'value': [{'dateLastCrawled': '2022-02-25T11:52:00.0000000Z',
#                          'deepLinks': [{'deepLinks': [{'name': 'Browsers',
#                                                        'url': 'https://www.microsoft.com/en-us/download/internet-explorer.aspx'},
#                                                       {'name': 'Xbox',
#                                                        'url': 'https://www.microsoft.com/en-us/download/xbox.aspx'},
#                                                       {'name': 'Developer '
#                                                                'Tools',
#                                                        'url': 'https://www.microsoft.com/en-us/download/developer-tools.aspx'},
#                                                       {'name': 'Drivers',
#                                                        'url': 'https://www.microsoft.com/en-us/download/driver.aspx'}],
#                                         'name': 'Download Center',
#                                         'snippet': 'Microsoft 365. Premium '
#                                                    'Office apps, extra cloud '
#                                                    'storage, advanced '
#                                                    'security, and more—all in '
#                                                    'one convenient '
#                                                    'subscription',
#                                         'url': 'https://www.microsoft.com/en-us/download'},
#                                        {'name': 'Microsoft Support',
#                                         'snippet': 'Contact Microsoft Support. '
#                                                    'Find solutions to common '
#                                                    'problems, or get help from '
#                                                    'a support agent.',
#                                         'url': 'https://support.microsoft.com/contactus'},
#                                        {'deepLinks': [],
#                                         'name': 'Account',
#                                         'snippet': 'Your Microsoft account '
#                                                    'comes with 5GB of storage '
#                                                    'and the option to add more '
#                                                    'when you need it. Learn '
#                                                    'more. Windows. Find, lock, '
#                                                    'or erase a lost or stolen '
#                                                    'Windows 10 device, '
#                                                    'schedule a repair, and get '
#                                                    'support. Learn more. '
#                                                    'Surface.',
#                                         'url': 'https://account.microsoft.com/account'},
#                                        {'deepLinks': [{'name': 'Compare All '
#                                                                'Microsoft 365 '
#                                                                'Plans',
#                                                        'url': 'https://www.microsoft.com/en-us/microsoft-365/buy/compare-all-microsoft-365-products'},
#                                                       {'name': 'Small Business',
#                                                        'url': 'https://www.microsoft.com/en-us/microsoft-365/business'},
#                                                       {'name': 'Office 365',
#                                                        'url': 'https://www.microsoft.com/en-us/microsoft-365/office-365'},
#                                                       {'name': 'Onedrive',
#                                                        'url': 'https://www.microsoft.com/en-us/microsoft-365/onedrive/online-cloud-storage'},
#                                                       {'name': 'Word',
#                                                        'url': 'https://www.microsoft.com/en-us/microsoft-365/word'},
#                                                       {'name': 'For Business',
#                                                        'url': 'https://www.microsoft.com/en-us/microsoft-365/business/compare-all-microsoft-365-business-products'}],
#                                         'name': 'Microsoft 365',
#                                         'snippet': 'Microsoft 365 '
#                                                    'subscriptions include a '
#                                                    'suite of familiar Office '
#                                                    'apps, intelligent cloud '
#                                                    'services, and world-class '
#                                                    'security in one place. '
#                                                    'Find the right plan for '
#                                                    'you.',
#                                         'url': 'https://www.microsoft.com/en-us/microsoft-365'},
#                                        {'name': 'Office',
#                                         'snippet': 'Microsoft 365—new name, '
#                                                    'same great value, same '
#                                                    'price. Productivity '
#                                                    'solutions for small and '
#                                                    'medium sized businesses.',
#                                         'url': 'https://www.microsoft.com/en-us/microsoft-365/microsoft-office'},
#                                        {'name': 'Microsoft Office Locations '
#                                                 'List',
#                                         'snippet': 'Microsoft U.S. office '
#                                                    'locations. Microsoft '
#                                                    'reaches customers at sales '
#                                                    'offices, support centers '
#                                                    'and technology centers '
#                                                    'throughout the country. '
#                                                    'Use the clickable map or '
#                                                    'the location links for '
#                                                    'more information.',
#                                         'url': 'https://www.microsoft.com/en-us/about/officelocator/all-offices'},
#                                        {'name': 'The Official Microsoft Blog',
#                                         'snippet': 'Microsoft Circular Centers '
#                                                    'build on our earlier '
#                                                    'circular cloud initiatives '
#                                                    'to extend the lifecycle of '
#                                                    'our servers and minimize '
#                                                    'the waste sent to '
#                                                    'landfills. In Amsterdam, '
#                                                    'our Microsoft Circular '
#                                                    'Center pilot reduced '
#                                                    'downtime at the datacenter '
#                                                    'and increased the '
#                                                    'availability of server and '
#                                                    'network parts for our own '
#                                                    'reuse and buy-back by our '
#                                                    'suppliers.',
#                                         'url': 'https://blogs.microsoft.com/blog/2020/08/04/microsoft-direct-operations-products-and-packaging-to-be-zero-waste-by-2030/'},
#                                        {'deepLinks': [{'name': 'Get Windows 10',
#                                                        'url': 'https://www.microsoft.com/en-us/windows/get-windows-10'},
#                                                       {'name': 'Apps',
#                                                        'url': 'https://www.microsoft.com/en-us/windows/windows-10-apps'},
#                                                       {'name': 'Security & '
#                                                                'Antivirus',
#                                                        'url': 'https://www.microsoft.com/en-us/windows/comprehensive-security'},
#                                                       {'name': 'Upgrade to The '
#                                                                'New Windows 11 '
#                                                                'OS',
#                                                        'url': 'https://www.microsoft.com/en-us/windows/windows-11'},
#                                                       {'name': 'Features',
#                                                        'url': 'https://www.microsoft.com/en-us/windows/features'},
#                                                       {'name': 'Help Me Choose',
#                                                        'url': 'https://www.microsoft.com/en-us/windows/help-me-choose'}],
#                                         'name': 'Windows',
#                                         'snippet': 'Discover the new Windows '
#                                                    '11 operating system from '
#                                                    'Microsoft, which features '
#                                                    'all the power and security '
#                                                    'of Windows 10 with a '
#                                                    'redesigned and refreshed '
#                                                    'look.',
#                                         'url': 'https://www.microsoft.com/en-us/windows/'}],
#                          'displayUrl': 'https://www.microsoft.com/en-us',
#                          'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.0',
#                          'isFamilyFriendly': True,
#                          'isNavigational': True,
#                          'language': 'en',
#                          'name': 'Microsoft – Cloud, Computers, Apps & Gaming',
#                          'snippet': 'Explore Microsoft products and services '
#                                     'for your home or business. Shop Surface, '
#                                     'Microsoft 365, Xbox, Windows, Azure, and '
#                                     'more. Find downloads and get support.',
#                          'url': 'https://www.microsoft.com/en-us/'},
#                         {'dateLastCrawled': '2022-03-03T12:54:00.0000000Z',
#                          'displayUrl': 'https://myaccount.microsoft.com',
#                          'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.1',
#                          'isFamilyFriendly': True,
#                          'isNavigational': False,
#                          'language': 'en',
#                          'name': 'My Account',
#                          'snippet': 'You need to enable JavaScript to run this '
#                                     'app. My Account. You need to enable '
#                                     'JavaScript to run this app.',
#                          'url': 'https://myaccount.microsoft.com/'},
#                         {'dateLastCrawled': '2022-02-25T11:31:00.0000000Z',
#                          'displayUrl': 'https://support.microsoft.com',
#                          'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.2',
#                          'isFamilyFriendly': True,
#                          'isNavigational': False,
#                          'language': 'en',
#                          'name': 'Microsoft Support',
#                          'snippet': 'Microsoft support is here to help you '
#                                     'with Microsoft products. Find how-to '
#                                     'articles, videos, and training for '
#                                     'Office, Windows, Surface, and more.',
#                          'url': 'https://support.microsoft.com/'},
#                         {'dateLastCrawled': '2022-03-07T13:16:00.0000000Z',
#                          'displayUrl': 'https://www.office.com',
#                          'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.3',
#                          'isFamilyFriendly': True,
#                          'isNavigational': False,
#                          'language': 'en',
#                          'name': 'Office 365 login',
#                          'snippet': 'Collaborate for free with online versions '
#                                     'of Microsoft Word, PowerPoint, Excel, and '
#                                     'OneNote. Save documents, spreadsheets, '
#                                     'and presentations online, in OneDrive.',
#                          'url': 'https://www.office.com/'},
#                         {'dateLastCrawled': '2022-03-04T09:25:00.0000000Z',
#                          'displayUrl': 'https://www.service-center-locator.com/microsoft/illinois/microsoft-chicago-illinois.htm',
#                          'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.4',
#                          'isFamilyFriendly': True,
#                          'isNavigational': False,
#                          'language': 'en',
#                          'name': 'Microsoft Repairs Chicago (Illinois), '
#                                  'Microsoft Service ...',
#                          'snippet': 'Microsoft technical support center in '
#                                     'Chicago, Illinois . Microsoft Corp. 77 W '
#                                     'Wacker Dr 2300 Chicago, IL 60601 (312) '
#                                     '251-5500. Microsoft Corp. 1520 Chicago '
#                                     'Ave Evanston, IL 60201 (847) 864-4777. '
#                                     'Microsoft Store. 49 Oakbrook Ctr Oak '
#                                     'Brook, IL 60523 (630) 288-3420. Microsoft '
#                                     'Corp. 2200 Busse Rd Elk Grove Village, IL '
#                                     '60007',
#                          'url': 'https://www.service-center-locator.com/microsoft/illinois/microsoft-chicago-illinois.htm'},
#                         {'dateLastCrawled': '2022-03-05T08:18:00.0000000Z',
#                          'displayUrl': 'https://www.datacenters.com/microsoft-chicago',
#                          'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.5',
#                          'isFamilyFriendly': True,
#                          'isNavigational': False,
#                          'language': 'en',
#                          'name': 'Microsoft: Chicago Northlake Data Center',
#                          'snippet': "Microsoft's new $500 million Chicago data "
#                                     'center is one of the largest data centers '
#                                     'ever built, spanning more than 700,000 '
#                                     "square feet. But it's also one of the "
#                                     'most unusual, with its garage-like lower '
#                                     'level optimized for 40-foot shipping '
#                                     'containers packed with web servers, while '
#                                     'a second story houses traditional '
#                                     'raised-floor data center space.',
#                          'url': 'https://www.datacenters.com/microsoft-chicago-northlake'}],
#               'webSearchUrl': 'https://www.bing.com/search?q=Microsoft'}}
