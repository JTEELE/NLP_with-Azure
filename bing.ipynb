# %%
query = input("e.g. Harley Davidson")
# -*- coding: utf-8 -*-

import json
import os 
from pprint import pprint
import nltk
import requests
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd
import re
import requests
from _functions import *
from nltk.util import ngrams
from collections import Counter
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

'''
This sample makes a call to the Bing Web Search API with a query and returns relevant web search.
Documentation: https://docs.microsoft.com/en-us/bing/search-apis/bing-web-search/overview
'''

# Add your Bing Search V7 subscription key and endpoint to your environment variables.
subscription_key = os.environ['BINGNEWS_API_ONE']
endpoint = os.environ['BING_ENDPOINT'] + "v7.0/search"

search_url = "https://api.bing.microsoft.com/v7.0/news/search"
headers = {"Ocp-Apim-Subscription-Key" : subscription_key}
params  = {"q": query, "textDecorations": True, "textFormat": "HTML"}
response = requests.get(search_url, headers=headers, params=params)
response.raise_for_status()
search_results = response.json()

# for word in search_results:
#     print(word)
# search_results = json.dumps(response.json())
# clean_text(search_results)

total_dataset = []
article = search_results["value"]
for substance in article:
    paragraph = (substance["description"])
    total_dataset.append(paragraph)

string = total_dataset.copy()
big_string = ' '.join(string)
print(total_dataset[:10])
# Out:
# ['A modernized take on the 1983 Harley-Davidson FXRT that salutes &#39;80s California counter-culture and is equipped with one hell of an engine.', 'Harley-Davidson Inc shares are currently trading -0.91% on the day. The chart below shows the one year performance of HOG shares, versus its 200 day moving average: Looking at the chart above, HOG&#39;s low point in its 52 week range is $29.', 'The party begins Thursday for Harley-Davidson riders. The company is celebrating its 119th anniversary this weekend. While the Harley-Davidson Museum is the center of the Hometown Rally and a celebration of all things Harley-Davidson,', 'So if this idea of high risk and high reward doesn&#39;t suit, you might be more interested in profitable, growing companies, like Harley-Davidson (NYSE:HOG). While profit isn&#39;t the sole metric that should be considered when investing,', 'After releasing two electric motorcycles at higher price points, LiveWire&#39;s forthcoming Del Mar motorcycle hopes to target daily commuters.', 'The bolt-on accessory that turned your Harley into a hauler. It’s almost Labor Day weekend here in the ‘States, so what better time to take a look at a rare and unique piece of American motorcycling history?', 'Harley-Davidson, Greif, Bank of Montreal, Ubiquiti and Northrim BanCorp are part of The Zacks top Analyst Blog.', 'One of the cool things about any Harley-Davidson event is just checking out other people&#39;s bikes – no two are alike. &quot;There’s no place you can’t take this motorcycle,&quot; said Rob Grimsley. Grimsley spent most of his career as a Charleston,', 'Harley&#39;s Hometown Rally is rumbling through Monday, Sept. 5, 2022 – and hundreds of riders hope a weekend fundraiser will put veterans front and center.', 'Davidson&#39;s Icons Collection is the Low Rider ST-based El Diablo. It&#39;s a 1980s-inspired bike with an intricate paint job.']

# %%
word_counter(string)
# Out:
#              word  count
# 0  harleydavidson      8
# 1            take      3
# 2             one      3
# 3             day      3
# 4           rider      3
# 5         weekend      3
# 6           share      2
# 7           chart      2
# 8             low      2
# 9           point      2

# %%
bigram_counter(string)
# Out:
#                          bigram  count
# 0             (hometown, rally)      2
# 1       (thing, harleydavidson)      2
# 2            (modernized, take)      1
# 3        (take, harleydavidson)      1
# 4        (harleydavidson, fxrt)      1
# 5                (fxrt, salute)      1
# 6          (salute, california)      1
# 7  (california, counterculture)      1
# 8    (counterculture, equipped)      1
# 9               (equipped, one)      1

# %%
# big_string
