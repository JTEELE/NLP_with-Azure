# %%
query = input("e.g. Harley Davidson")
# -*- coding: utf-8 -*-

import json
import os 
from pprint import pprint
import nltk
import requests
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd
import re
import requests
from _functions import *
from nltk.util import ngrams
from collections import Counter
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

'''
This sample makes a call to the Bing Web Search API with a query and returns relevant web search.
Documentation: https://docs.microsoft.com/en-us/bing/search-apis/bing-web-search/overview
'''

# Add your Bing Search V7 subscription key and endpoint to your environment variables.
subscription_key = os.environ['BINGNEWS_API']
endpoint = os.environ['BING_ENDPOINT'] + "v7.0/search"

search_url = "https://api.bing.microsoft.com/v7.0/news/search"
headers = {"Ocp-Apim-Subscription-Key" : subscription_key}
params  = {"q": query, "textDecorations": True, "textFormat": "HTML"}
response = requests.get(search_url, headers=headers, params=params)
response.raise_for_status()
search_results = response.json()

# for word in search_results:
#     print(word)
# search_results = json.dumps(response.json())
# clean_text(search_results)

total_dataset = []
article = search_results["value"]
for substance in article:
    paragraph = (substance["description"])
    total_dataset.append(paragraph)

string = total_dataset.copy()
big_string = ' '.join(string)
print(total_dataset[:10])
# Out:
# ['I n the latest trading session, Harley-Davidson (HOG) closed at $38.80, marking a -0.72% move from the previous day. This move lagged the S&amp;P 500&#39;s daily loss of 0.43%. Meanwhile,', 'I t has been about a month since the last earnings report for Harley-Davidson (HOG). Shares have lost about 9.8% in that time frame, underperforming the S&amp;P 500. Will the recent n', 'Harley-Davidson and Volkswagen rank just under Disney and Nintendo in the top ten of tattoos representing the brands on Instagram.', 'Back in 2020 when the NHL was dealing with COVID restrictions and trying to find a way to hold the Stanley Cup Playoffs, the plan of a bubble was broached, and that created a need for the ability to deal with injuries and illnesses while still maintaining a regular schedule.', 'The latest trend in street bikes is the performance bagger. The style incorporates the ever-popular “bagger” motorcycle (really, just a cruiser with saddlebags) modified for performance and/or agility.', 'XIFIN Welcomes Harley Ross as Chief Commercial Officer. XIFIN today announced the appointment of Harley Ross as chief commercial officer, a newly-created position. Reporting direc', 'Harley-Davidson let Cycle News&#39; journalist take a few laps on the MotoAmerica’s King of the Baggers series-winning Screamin’ Eagle Road Glide.', 'Harley Quinn season 3 has just entered the audio mixing stage, says co-creator Patrick Schumacker. This adult animation, based on DC Comics characters, blew a storm through the TV landscape back in 2019,', 'The Uplive WorldStage Singing Competition announced its 2021 winners. The overall Grand Prize was awarded to the gifted 22-year-old singer and performer from']

# %%
word_counter(string)
# Out:
#              word  count
# 0  harleydavidson      4
# 1              wa      3
# 2          harley      3
# 3               n      2
# 4          latest      2
# 5             hog      2
# 6            move      2
# 7           sampp      2
# 8              ha      2
# 9            back      2

# %%
bigram_counter(string)
# Out:
#                       bigram  count
# 0      (harleydavidson, hog)      2
# 1             (harley, ross)      2
# 2              (ross, chief)      2
# 3        (chief, commercial)      2
# 4      (commercial, officer)      2
# 5                (n, latest)      1
# 6          (latest, trading)      1
# 7         (trading, session)      1
# 8  (session, harleydavidson)      1
# 9              (hog, closed)      1

# %%
# big_string
